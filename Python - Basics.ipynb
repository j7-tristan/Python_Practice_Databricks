# %% [markdown]
# Functions

# %%
print('My age is ' + 25)

# %%
print ('My age is' + ' 36')

# %%
print("Hello" + " " "future" + " " "python!")

print("Hi" + " " "Earth" + " " "Jesus Is Coming1")

# %%
print(1, 2, 3, 4, sep='#', end='&')

print(1, 3, 5, 7, sep='/', end=' Nice')
